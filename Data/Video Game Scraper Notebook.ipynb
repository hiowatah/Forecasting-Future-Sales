# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import time

# %%
#to loop through the urls to scrape a year's worth of data. Starting point is week ending Janaury 7, 2017

# %%
#empty lists to gather my data
game_title = []
weekly_sales = []
total_sales = []
num_weeks_out = []

# %%
def webscraper(starting):
    url = 'http://www.vgchartz.com/weekly/' + starting +'/Global/'
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    weekly_data = []
    counter = 4
    while counter <=62:
        for info in soup.find('div', id = 'mainContainerSub').div.div.div.find_all('tr')[counter].find_all('td'):
            weekly_data.append(info.text)
        counter +=2
    
    return weekly_data

# %%
def data_collector(game_title, weekly_sales, total_sales, num_weeks_out, webscraper):
    game_title.append(webscraper[3::7])
    weekly_sales.append(webscraper[4::7])
    total_sales.append(webscraper[5::7])
    num_weeks_out.append(webscraper[6::7])
    
    return game_title, weekly_sales, total_sales, num_weeks_out

# %%
#Original Starting Point is 42743 - while loop breaks because the site has no data for week of 9/16/2017.
starting_point = 39493

while starting_point <= 43464:
    a = webscraper(str(starting_point))
    b = data_collector(game_title, weekly_sales, total_sales, num_weeks_out, a)
    starting_point+=7
    time.sleep(3)

# %%
game_title
# Out:
# [['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
# ...
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action'],
#  ['Super Smash Bros. (2018) (NS)Nintendo, Fighting',
#   'Red Dead Redemption 2 (PS4)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (PS4)Activision, Shooter',
#   'Mario Kart 8 Deluxe (NS)Nintendo, Racing',
#   'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure',
#   'Super Mario Party (NS)Nintendo, Party',
#   'FIFA 19 (PS4)Electronic Arts, Sports',
#   "Pokemon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing",
#   'Red Dead Redemption 2 (XOne)Take-Two Interactive, Action-Adventure',
#   'Call of Duty: Black Ops IIII (XOne)Activision, Shooter',
#   'Battlefield V (PS4)Electronic Arts, Shooter',
#   'Super Mario Odyssey (NS)Nintendo, Platform',
#   "Pokemon: Let's Go, Eevee! (NS)Nintendo, Role-Playing",
#   "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure",
#   'Spyro Reignited Trilogy (PS4)Activision, Platform',
#   'The Legend of Zelda: Breath of the Wild (NS)Nintendo, Action-Adventure',
#   'Battlefield V (XOne)Electronic Arts, Shooter',
#   'Minecraft (NS)Mojang, Sandbox',
#   'Forza Horizon 4 (XOne)Microsoft Studios, Racing',
#   'NBA 2K19 (PS4)Take-Two Interactive, Sports',
#   'Grand Theft Auto V (PS4)Take-Two Interactive, Action',
#   'God of War (PS4) (PS4)Sony Interactive Entertainment, Action',
#   'Splatoon 2 (NS)Nintendo, Shooter',
#   'FIFA 19 (XOne)Electronic Arts, Sports',
#   'Just Cause 4 (PS4)Square Enix, Action-Adventure',
#   'NBA 2K19 (XOne)Take-Two Interactive, Sports',
#   'Madden NFL 19 (PS4)Electronic Arts, Sports',
#   "Assassin's Creed Odyssey (XOne)Ubisoft, Action-Adventure",
#   'Grand Theft Auto V (XOne)Take-Two Interactive, Action',
#   'Fortnite (XOne)Gearbox Software, Action']]

# %%
"""
Skipped week ending September 16, 2017,
"""
# Out:
# '\nSkipped week ending September 16, 2017,\n'

# %%
#to consolidate each list of list into 1 list and add to pandas dataframe
def flattener(many_lists):
    flat_list = []
    for sublist in many_lists:
        for item in sublist:
            flat_list.append(item)
    return flat_list

# %%
games = flattener(game_title)
weekly_sales_nums = flattener(weekly_sales)
all_time_sales = flattener(total_sales)
weeks_out = flattener(num_weeks_out)

# %%
df = pd.DataFrame(columns=['Game Title', 'Weekly Sales', 'All Time Sales', 'Weeks Out'])

# %%
df['Game Title'] = games
df['Weekly Sales'] = weekly_sales_nums
df['All Time Sales'] = all_time_sales
df['Weeks Out'] = weeks_out

# %%
df.to_csv('Video_Game_Data.csv')

# %%
df.head()
# Out:
#                                           Game Title Weekly Sales  \
# 0    Super Smash Bros. (2018) (NS)Nintendo, Fighting    1,103,894
# 1  Red Dead Redemption 2 (PS4)Take-Two Interactiv...      705,407
# 2  Call of Duty: Black Ops IIII (PS4)Activision, ...      511,667
# 3           Mario Kart 8 Deluxe (NS)Nintendo, Racing      438,400
# 4  Spider-Man (PS4) (PS4)Sony Interactive Enterta...      426,691
#
#   All Time Sales Weeks Out
# 0      8,951,009         4
# 1     13,940,203        10
# 2      9,317,241        12
# 3     13,046,117        88
# 4      8,757,859        17
